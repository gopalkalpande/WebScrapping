# %%
import json

# Specify the path to the JSON file
file_path = "data/inputJSONs/9.json"

# Read the JSON file
with open(file_path, "r") as file:
    json_data = json.load(file)

# %%
json_keys = list(json_data.keys())

# %%
# 0
plain_dict = {'giataId': json_data[json_keys[0]]}

# %%
plain_dict[json_keys[1]+'_value'] = str
plain_dict[json_keys[1]+'_locale'] = str
# plain_dict
# 1
for dict_ in json_data[json_keys[1]]:
    if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[1]+'_value'] = dict_['value']
        plain_dict[json_keys[1]+'_locale'] = dict_['locale']

# %%
# 2

plain_dict[json_keys[2]+'_giataId'] = json_data[json_keys[2]]['giataId']

for dict_ in json_data[json_keys[2]]['names']:
    if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[2]+'_value'] = dict_['value']
        plain_dict[json_keys[2]+'_locale'] = dict_['locale']

# %%
# 3

key_id = 3
plain_dict[json_keys[key_id]+'_giataId'] = json_data[json_keys[key_id]]['giataId']

for dict_ in json_data[json_keys[key_id]]['names']:
    if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[key_id]+'_value'] = dict_['value']
        plain_dict[json_keys[key_id]+'_locale'] = dict_['locale']

# %%
# 4

key_id = 4
plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']

for dict_ in json_data[json_keys[key_id]]['names']:
    if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[key_id]+'_value'] = dict_['value']
        plain_dict[json_keys[key_id]+'_locale'] = dict_['locale']

# %%
# 5
key_id = 5

plain_dict['source'] = json_data[json_keys[key_id]]

# %%
# 6

key_id = 6
# plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']

for dict_ in json_data[json_keys[key_id]]:
    if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[key_id]+'_value'] = dict_['value']
        # plain_dict[json_keys[key_id]+'_locale'] = dict_['locale']

# %%
# 7

key_id = 7
# plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']

for dict_ in json_data[json_keys[key_id]]:
    # if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
    plain_dict[json_keys[key_id]+'_value_addressLines'] = ', '.join(dict_['addressLines'])
    plain_dict[json_keys[key_id]+'_street'] = dict_['street']
    plain_dict[json_keys[key_id]+'_zip'] = dict_['zip']
    plain_dict[json_keys[key_id]+'_cityName'] = dict_['cityName']
    plain_dict[json_keys[key_id]+'_poBox'] = dict_['poBox']

# %%
# 8

key_id = 8
# plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']
ph_ = []
fax_ = []
for dict_ in json_data[json_keys[key_id]]:
    # print(type(ph_))
    # print('8', dict_)
    
    if dict_['tech']=='phone':
        # print('11',dict_['phone'])
        ph_.append(str(dict_['phone']))
        # print(ph_)
    else:
        fax_.append(dict_['phone'])
    
    plain_dict[json_keys[key_id]+'_phone'] = ph_
    plain_dict[json_keys[key_id]+'_fax'] = fax_

# %%
# 10

key_id = 10
# plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']
url_ = []

for dict_ in json_data[json_keys[key_id]]:
        url_.append(str(dict_['url']))
    
plain_dict[json_keys[key_id]] = url_

# %%
# 11

key_id = 11
# plain_dict[json_keys[key_id]+'_code'] = json_data[json_keys[key_id]]['code']

for dict_ in json_data[json_keys[key_id]]:
    # if 'isDefault' in dict_.keys() and dict_['isDefault']==True:
        plain_dict[json_keys[key_id]+'_latitude'] = dict_['latitude']
        plain_dict[json_keys[key_id]+'_longitude'] = dict_['longitude']
        plain_dict[json_keys[key_id]+'_accuracy'] = dict_['accuracy']

# %%
# 12

key_id = 12

giataId_ = []
names_ = []
for dict_ in json_data[json_keys[key_id]]:
    giataId_.append(dict_['giataId'])
    if 'names' in dict_.keys():
        for names_dict in dict_['names']:
            if 'isDefault' in names_dict.keys() and names_dict['isDefault']==True and names_dict['locale'] =='en':
                names_.append(names_dict['value'])
                

plain_dict[json_keys[key_id]+'_giataId'] = giataId_
plain_dict[json_keys[key_id]+'_names'] = names_

# %%
# 13

# need to iterate overmultiple JSONs to learn about the variety of the attributes
dictSet = {}
for dict_ in json_data[json_keys[13]]:
    # print(dict_.keys())
    for key_ in dict_.keys():
        if isinstance(dict_.get(key_), dict):
            for key__ in dict_.get(key_).keys():
                # print('_'.join([key_,key__]))
                dictSet['_'.join([key_,key__])] = []
                # print()
        else: 
            dictSet[key_] = []


for dict_ in json_data[json_keys[13]]:
    for key_ in dictSet.keys():
        if '_' not in key_: # isinstance(dict_.get(key_), dict):
            dictSet[key_].append(dict_.get(key_))
        elif isinstance(dict_.get(key_), dict):
            dictSet[key_].append(dict_.get(key_.split('_')[0]).get(key_.split('_')[1]))
            print(key_, '\t', key__, '\t', dict_.get(key_.split('_')[0]).get(key_.split('_')[1]))
        else:
            dictSet[key_].append(dict_.get(key_))
        # print(key_, dict_.get(key_), type(dict_.get(key_)))
    # print('-'*10)


for subKey in dictSet.keys():
    plain_dict['_'.join([json_keys[13], subKey])] = dictSet[subKey]

# %%
# 14

# need to iterate overmultiple JSONs to learn about the variety of the attributes
dictSet = {}
for dict_ in json_data[json_keys[14]]:
    # print(dict_.keys())
    for key_ in dict_.keys():
        if isinstance(dict_.get(key_), dict) and key_!='sizes':
            for key__ in dict_.get(key_).keys():
                # print('_'.join([key_,key__]))
                dictSet['_'.join([key_,key__])] = []
                # print()
        else: 
            dictSet[key_] = []
dictSet['herf'] = []

for dict_ in json_data[json_keys[14]]:
    hrefs = []
    for key_ in dictSet.keys():
        # if '_' not in key_: # isinstance(dict_.get(key_), dict):
            # dictSet[key_].append(dict_.get(key_))
        if isinstance(dict_.get(key_), dict) and key_=='sizes':
            # print(key_, '\n', list(dict_[key_].keys()))
            dictSet[key_].append(list(dict_[key_].keys()))
            # print(dict_.get(key_))
            imgDict = dict_.get(key_)
            for key__ in imgDict.keys():
                # print(imgDict[key__].keys())
                hrefs.append(imgDict[key__]['href'])
            # print(key_, '\t', key__, '\t', dict_.get(key_.split('_')[0]).get(key_.split('_')[1]))
        elif key_ == 'herf':
            dictSet[key_].append(hrefs)
        else:
            dictSet[key_].append(dict_.get(key_))
        # print(key_, dict_.get(key_), type(dict_.get(key_)))
    # print('-'*10)


for subKey in dictSet.keys():
    plain_dict['_'.join([json_keys[14], subKey])] = dictSet[subKey]

# %%
# 15

# need to iterate overmultiple JSONs to learn about the variety of the attributes
dictSet = set()
dictSetNested = set()
for key_ in json_data[json_keys[15]].keys():
    # print(json_data[json_keys[15]][key_], '\n\n')
    for list_item in json_data[json_keys[15]][key_]:
        for listKey in list_item.keys():
            dictSet.add(listKey)
            if isinstance(list_item[listKey], dict):
                # print(list_item[listKey])
                for nestedKey_ in list_item[listKey].keys():
                    # print(nestedKey_, list_item[listKey][nestedKey_])
                    for nestedKey__, value_ in list_item[listKey][nestedKey_].items():
                        # print(nestedKey__, value_)
                        dictSetNested.add(nestedKey__)
            
# print('\n\n', dictSet, '\n\n', dictSetNested)

# check inclusion 1
# Use this code for id 15
dataDict = {'factDefId':[], 'attributes_attributeDefId':[], 'attributes_value':[], 'attributes_unitDefId':[]}
# dictSet = set()
# dictSetNested = set()
json_ = json_data[json_keys[15]]
# print(type(json_))
for key_0 in json_.keys():
    # print(json_data[json_keys[15]][key_], '\n\n')
    for list_item in json_[key_0]:
        dataDict_ = {'factDefId':[], 'attributes_attributeDefId':[], 'attributes_value':[], 'attributes_unitDefId':[]}
        for key_1, value_1 in list_item.items():
            # print(listKey)
            if isinstance(value_1, str):
                # dataDict[key_1].append(value_1)
                dataDict_[key_1] = value_1
            elif isinstance(value_1, dict):
                # print(list_item[listKey])
                for key_2, value_2 in value_1.items():
                    if isinstance(value_2, str):
                        jointKey = '_'.join([key_1, key_2])
                        # print('#18', jointKey)
                        # dataDict[jointKey].append(value_2)
                        dataDict_[jointKey] = value_2
                    elif isinstance(value_2, dict):
                        for key_3, value_3 in value_2.items():
                            jointKey = '_'.join([key_1, key_3])
                            # print('#23', jointKey)
                            # dataDict[jointKey].append(value_3)
                            dataDict_[jointKey] = value_3
                            # print(key_3, value_3)
                            # pass
        for key in dataDict.keys():
                        if dataDict_[key]:
                            dataDict[key].append(str(dataDict_[key]))
                        else:
                            dataDict[key].append(None)
# print('\n\n', dataDict)

for subKey in dataDict.keys():
    plain_dict['_'.join([json_keys[15], subKey])] = dataDict[subKey]

# %%
# 16

plain_dict[json_keys[16]] = json_data[json_keys[16]]

# %%
# 17

textsData = {}
for data_ in json_data[json_keys[17]]['en']['sections']:
    dataItems = data_.items()
    key = ''
    value = ''
    for key_, value_ in dataItems:
        if key_ == 'title':
            key = value_
        else:
            textsData['_'.join(['texts','en',key])] = value_
# print(textsData)

for data_ in json_data[json_keys[17]]['en-US']['sections']:
    dataItems = data_.items()
    key = ''
    value = ''
    for key_, value_ in dataItems:
        if key_ == 'title':
            key = value_
        else:
            textsData['_'.join(['texts','en-US',key])] = value_
# print(textsData)

for subKey in textsData.keys():
    plain_dict[subKey] = textsData[subKey]

# %%
list(plain_dict.keys())
# Out:
# ['giataId',
#  'names_value',
#  'names_locale',
#  'city_giataId',
#  'city_value',
#  'city_locale',
#  'destination_giataId',
#  'destination_value',
#  'destination_locale',
#  'country_code',
#  'country_value',
#  'country_locale',
#  'source',
#  'ratings_value',
#  'addresses_value_addressLines',
#  'addresses_street',
#  'addresses_zip',
#  'addresses_cityName',
#  'addresses_poBox',
#  'phones_phone',
#  'phones_fax',
#  'urls',
#  'geoCodes_latitude',
#  'geoCodes_longitude',
#  'geoCodes_accuracy',
#  'chains_giataId',
#  'chains_names',
#  'roomTypes_variantId',
#  'roomTypes_category',
#  'roomTypes_categoryInformation_attributeDefId',
#  'roomTypes_categoryInformation_name',
#  'roomTypes_view',
#  'roomTypes_viewInformation_attributeDefId',
#  'roomTypes_viewInformation_name',
#  'roomTypes_imageRelations',
#  'roomTypes_type',
#  'roomTypes_typeInformation_attributeDefId',
#  'roomTypes_typeInformation_name',
#  'roomTypes_name',
#  'images_id',
#  'images_motifType',
#  'images_lastUpdate',
#  'images_heroImage',
#  'images_baseName',
#  'images_sizes',
#  'images_herf',
#  'facts_factDefId',
#  'facts_attributes_attributeDefId',
#  'facts_attributes_value',
#  'facts_attributes_unitDefId',
#  'variantGroups',
#  'texts_en_Location',
#  'texts_en_Facilities',
#  'texts_en_Rooms',
#  'texts_en_Sports/Entertainment',
#  'texts_en_Meals',
#  'texts_en_Payment',
#  'texts_en-US_Location',
#  'texts_en-US_Facilities',
#  'texts_en-US_Rooms',
#  'texts_en-US_Sports/Entertainment',
#  'texts_en-US_Meals',
#  'texts_en-US_Payment']
